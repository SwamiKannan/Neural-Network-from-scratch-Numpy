# %% [markdown]
# ### MNIST neural network from scratch

# %% [markdown]
# #### Fully Connected Layer (Linear Layer)

# %%
import numpy as np 

class Linear():
    def __init__(self, in_size, out_size):
        self.W = np.random.randn(in_size, out_size) * 0.01
        self.b = np.zeros((1, out_size))
        self.params = [self.W, self.b]
        self.gradW = None
        self.gradB = None
        self.gradInput = None        

    def forward(self, X):
        self.X = X
        self.output = np.dot(X, self.W) + self.b
        return self.output

    def backward(self, nextgrad):
        self.gradW = np.dot(self.X.T, nextgrad)
        self.gradB = np.sum(nextgrad, axis=0)
        self.gradInput = np.dot(nextgrad, self.W.T)
        return self.gradInput, [self.gradW, self.gradB]

# %%
np.random.seed(3)

# %% [markdown]
# #### Rectified Linear Activation Layer (ReLU)

# %%
class ReLU():
    def __init__(self):
        self.params = []
        self.gradInput = None

    def forward(self, X):
        self.output = np.maximum(X, 0)
        return self.output

    def backward(self, nextgrad):
        self.gradInput = nextgrad.copy()
        self.gradInput[self.output <=0] = 0
        return self.gradInput, []

# %% [markdown]
# #### Defining the softmax function

# %%
def softmax(x):
    exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    out= exp_x / np.sum(exp_x, axis=1, keepdims=True)
    return out

# %% [markdown]
# #### Defining the Cross Entropy Loss

# %%
class CrossEntropy:
    def forward(self, X, y):
        self.m = y.shape[0]
        self.p = softmax(X)
        cross_entropy = -np.log(self.p[range(self.m), y])
        loss = cross_entropy[0] / self.m
        return loss
    
    def backward(self, X, y):
        y_idx = y.argmax()        
        grad = softmax(X)
        grad[range(self.m), y] -= 1
        grad /= self.m
        return grad

# %% [markdown]
# #### Loading the MNIST dataset

# %%
from keras.datasets import mnist
from keras.utils import np_utils


(train_features, train_targets), (test_features, test_targets) = mnist.load_data()


train_features = train_features.reshape(60000, 784)
print(train_features.shape)
test_features = test_features.reshape(10000, 784)
print(test_features.shape)


# # normalize inputs from 0-255 to 0-1
train_features = train_features / 255.0
test_features = test_features / 255.0

print(train_targets.shape)
print(test_targets.shape)

X_train = train_features
y_train = train_targets

X_val = test_features
y_val = test_targets
# Out:
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# visualizing the first 10 images in the dataset and their labels
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 1))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i].reshape(28, 28), cmap="gray")
    plt.axis('off')
plt.show()
print('label for each of the above image: %s' % (y_train[0:10]))
# Out:
# label for each of the above image: [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# #### Here, we define the container NN class that enables the forward prop and backward propagation of the entire network. Note, how this class enables us to add layers of different types and also correctly pass gradients using the chain rule.

# %%
class NN():
    def __init__(self, lossfunc=CrossEntropy()):
        self.params = []
        self.layers = []
        self.loss_func = lossfunc
        self.grads = []
        
    def add_layer(self, layer):
        self.layers.append(layer)
        self.params.append(layer.params)

    def forward(self, X):
        for layer in self.layers:
            X = layer.forward(X)
        return X
    
    def backward(self, nextgrad):
        self.clear_grad_param()
        for layer in reversed(self.layers):
            nextgrad, grad = layer.backward(nextgrad)
            self.grads.append(grad)
        return self.grads
    
    def train_step(self, X, y):
        out = self.forward(X)
        loss = self.loss_func.forward(out,y)
        nextgrad = self.loss_func.backward(out,y)
        l2 = self.backward(nextgrad)
        return loss, l2
    
    def predict(self, X):
        X = self.forward(X)
        return np.argmax(X, axis=1)
    
    def predict_scores(self, X):
        X = self.forward(X)
        return X
    
    def clear_grad_param(self):
        self.grads = []

# %% [markdown]
# #### Defining the update function (SGD with momentum)

# %%
def update_params(velocity, params, grads, learning_rate=0.01, mu=0.9):
    for v, p, g, in zip(velocity, params, reversed(grads)):
        for i in range(len(g)):
            v[i] = mu * v[i] + learning_rate * g[i]
            p[i] -= v[i]
            print('Max gradient value:',np.amax(v[i]))
            print('Gradient shape:',v[i].shape)

# %% [markdown]
# #### Defining a function which gives us the minibatches (both the datapoint and the corresponding label)

# %%
# get minibatches
def minibatch(X, y, minibatch_size):
    n = X.shape[0]
    minibatches = []
    permutation = np.random.permutation(X.shape[0])
    X = X[permutation]
    y = y[permutation]
    
    for i in range(0, n , minibatch_size):
        X_batch = X[i:i + minibatch_size, :]
        y_batch = y[i:i + minibatch_size, ]
        minibatches.append((X_batch, y_batch))
        
    return minibatches

# %% [markdown]
# #### The traning loop

# %%
def train(net, X_train, y_train, minibatch_size, epoch, learning_rate, mu=0.9, X_val=None, y_val=None):
    val_loss_epoch = []
    minibatches = minibatch(X_train, y_train, minibatch_size)
    minibatches_val = minibatch(X_val, y_val, minibatch_size)

    
    for i in range(epoch):
        loss_batch = []
        val_loss_batch = []
        velocity = []
        for param_layer in net.params:
            p = [np.zeros_like(param) for param in list(param_layer)]
            velocity.append(p)
            
        # iterate over mini batches
        for X_mini, y_mini in minibatches:
            loss, grads = net.train_step(X_mini, y_mini)
            loss_batch.append(loss)
            update_params(velocity, net.params, grads, learning_rate=learning_rate, mu=mu)

        for X_mini_val, y_mini_val in minibatches_val:
            val_loss, _ = net.train_step(X_mini, y_mini)
            val_loss_batch.append(val_loss)
        
        # accuracy of model at end of epoch after all mini batch updates
        m_train = X_train.shape[0]
        m_val = X_val.shape[0]
        y_train_pred = np.array([], dtype="int64")
        y_val_pred = np.array([], dtype="int64")
        y_train1 = []
        y_vall = []
        for i in range(0, m_train, minibatch_size):
            X_tr = X_train[i:i + minibatch_size, : ]
            y_tr = y_train[i:i + minibatch_size,]
            y_train1 = np.append(y_train1, y_tr)
            y_train_pred = np.append(y_train_pred, net.predict(X_tr))

        for i in range(0, m_val, minibatch_size):
            X_va = X_val[i:i + minibatch_size, : ]
            y_va = y_val[i:i + minibatch_size,]
            y_vall = np.append(y_vall, y_va)
            y_val_pred = np.append(y_val_pred, net.predict(X_va))
            
        train_acc = check_accuracy(y_train1, y_train_pred)
        val_acc = check_accuracy(y_vall, y_val_pred)

        mean_train_loss = sum(loss_batch) / float(len(loss_batch))
        mean_val_loss = sum(val_loss_batch) / float(len(val_loss_batch))
        
        val_loss_epoch.append(mean_val_loss)
        print("Loss = {0} | Training Accuracy = {1} | Val Loss = {2} | Val Accuracy = {3}".format(mean_train_loss, train_acc, mean_val_loss, val_acc))
    return net

# %% [markdown]
# #### Checking the accuracy of the model

# %%
def check_accuracy(y_true, y_pred):
    return np.mean(y_pred == y_true)

# %% [markdown]
# #### Invoking all that we have created until now

# %%
from random import shuffle

## input size
input_dim = X_train.shape[1]

## hyperparameters
iterations = 10
learning_rate = 0.1
hidden_nodes = 32
output_nodes = 10

## define neural net
nn = NN()
nn.add_layer(Linear(input_dim, hidden_nodes))
nn.add_layer(ReLU())
nn.add_layer(Linear(hidden_nodes, output_nodes))

nn = train(nn, X_train , y_train, minibatch_size=200, epoch=10, \
           learning_rate=learning_rate, X_val=X_val, y_val=y_val)
# Out:
# Max gradient value: 0.00026038031456142183
# Gradient shape: (784, 32)
# Max gradient value: 0.00017191222746638303
# Gradient shape: (1, 32)
# Max gradient value: 0.0007140627716474611
# Gradient shape: (32, 10)
# Max gradient value: 0.0029827438930338256
# Gradient shape: (1, 10)
# Max gradient value: 0.0004434548120853715
# Gradient shape: (784, 32)
# Max gradient value: 0.00016994000080155854
# Gradient shape: (1, 32)
# Max gradient value: 0.0011733991012077066
# Gradient shape: (32, 10)
# Max gradient value: 0.006815183488674488
# Gradient shape: (1, 10)
# Max gradient value: 0.0005500041968067802
# Gradient shape: (784, 32)
# Max gradient value: 0.00029874461521802245
# Gradient shape: (1, 32)
# Max gradient value: 0.0016384766992188517
# Gradient shape: (32, 10)
# Max gradient value: 0.008555379965284951
# Gradient shape: (1, 10)
# Max gradient value: 0.0006593041774626506
# Gradient shape: (784, 32)
# Max gradient value: 0.00026855909898079966
# Gradient shape: (1, 32)
# Max gradient value: 0.002255470418595532
# Gradient shape: (32, 10)
# Max gradient value: 0.008032476478197367
# Gradient shape: (1, 10)
# Max gradient value: 0.0007937794449693952
# Gradient shape: (784, 32)
# Max gradient value: 0.0003272990669589506
# Gradient shape: (1, 32)
# Max gradient value: 0.002689326883375003
# Gradient shape: (32, 10)
# Max gradient value: 0.007472725245199437
# Gradient shape: (1, 10)
# Max gradient value: 0.0008323319586391193
# Gradient shape: (784, 32)
# Max gradient value: 0.00029546512742127483
# Gradient shape: (1, 32)
# Max gradient value: 0.003235714951695492
# Gradient shape: (32, 10)
# Max gradient value: 0.0065893276264384895
# Gradient shape: (1, 10)
# Max gradient value: 0.000878979908711813
# Gradient shape: (784, 32)
# Max gradient value: 0.00027192740913543944
# Gradient shape: (1, 32)
# Max gradient value: 0.0037914871493728713
# Gradient shape: (32, 10)
# Max gradient value: 0.007897785344555838
# Gradient shape: (1, 10)
# Max gradient value: 0.0009965406300849547
# Gradient shape: (784, 32)
# Max gradient value: 0.0002554708600223655
# Gradient shape: (1, 32)
# Max gradient value: 0.004282217627527537
# Gradient shape: (32, 10)
# Max gradient value: 0.00861570041125594
# Gradient shape: (1, 10)
# Max gradient value: 0.0011260086365794228
# Gradient shape: (784, 32)
# Max gradient value: 0.0002267444125089266
# Gradient shape: (1, 32)
# Max gradient value: 0.004947016568821657
# Gradient shape: (32, 10)
# Max gradient value: 0.008165711831630514
# Gradient shape: (1, 10)
# Max gradient value: 0.001358812626294778
# Gradient shape: (784, 32)
# Max gradient value: 0.00021616797643941974
# Gradient shape: (1, 32)
# Max gradient value: 0.005677199194899375
# Gradient shape: (32, 10)
# Max gradient value: 0.008157403311357085
# Gradient shape: (1, 10)
# Max gradient value: 0.0016385747941655713
# Gradient shape: (784, 32)
# Max gradient value: 0.00020118166008699752
# Gradient shape: (1, 32)
# Max gradient value: 0.006276523510026057
# Gradient shape: (32, 10)
# Max gradient value: 0.00903403032787342
# Gradient shape: (1, 10)
# Max gradient value: 0.001891342227569437
# Gradient shape: (784, 32)
# Max gradient value: 0.0001759719790212056
# Gradient shape: (1, 32)
# Max gradient value: 0.007576075364205959
# Gradient shape: (32, 10)
# Max gradient value: 0.004188743732333522
# Gradient shape: (1, 10)
# Max gradient value: 0.0021742514771270305
# Gradient shape: (784, 32)
# Max gradient value: 0.00016217511716446677
# Gradient shape: (1, 32)
# Max gradient value: 0.008926672345700888
# Gradient shape: (32, 10)
# Max gradient value: 0.005249942837915184
# Gradient shape: (1, 10)
# Max gradient value: 0.0027563156116008985
# Gradient shape: (784, 32)
# Max gradient value: 0.0001546648647196644
# Gradient shape: (1, 32)
# Max gradient value: 0.01088720914222786
# Gradient shape: (32, 10)
# Max gradient value: 0.004817348966240198
# Gradient shape: (1, 10)
# Max gradient value: 0.0032422947199096594
# Gradient shape: (784, 32)
# Max gradient value: 0.00013919837824769797
# Gradient shape: (1, 32)
# Max gradient value: 0.013250675780395224
# Gradient shape: (32, 10)
# Max gradient value: 0.005093795254864369
# Gradient shape: (1, 10)
# Max gradient value: 0.004179446937627472
# Gradient shape: (784, 32)
# Max gradient value: 0.0003502930335378501
# Gradient shape: (1, 32)
# Max gradient value: 0.014665955272935247
# Gradient shape: (32, 10)
# Max gradient value: 0.007529359059461534
# Gradient shape: (1, 10)
# Max gradient value: 0.004572235167238819
# Gradient shape: (784, 32)
# Max gradient value: 0.0002920867465351182
# Gradient shape: (1, 32)
# Max gradient value: 0.017433900850588067
# Gradient shape: (32, 10)
# Max gradient value: 0.00490855873486613
# Gradient shape: (1, 10)
# Max gradient value: 0.0057437063887836775
# Gradient shape: (784, 32)
# Max gradient value: 0.0014770919013159314
# Gradient shape: (1, 32)
# Max gradient value: 0.019884517060253296
# Gradient shape: (32, 10)
# Max gradient value: 0.006593282118633467
# Gradient shape: (1, 10)
# Max gradient value: 0.006879683389755909
# Gradient shape: (784, 32)
# Max gradient value: 0.0016193990254565846
# Gradient shape: (1, 32)
# Max gradient value: 0.021562708392144206
# Gradient shape: (32, 10)
# Max gradient value: 0.008675715836986841
# Gradient shape: (1, 10)
# Max gradient value: 0.007392360829317622
# Gradient shape: (784, 32)
# Max gradient value: 0.00281705888108905
# Gradient shape: (1, 32)
# Max gradient value: 0.023951361042325817
# Gradient shape: (32, 10)
# Max gradient value: 0.016100328509029073
# Gradient shape: (1, 10)
# Max gradient value: 0.00783358005543162
# Gradient shape: (784, 32)
# Max gradient value: 0.0028995795906414817
# Gradient shape: (1, 32)
# Max gradient value: 0.02523116850354909
# Gradient shape: (32, 10)
# Max gradient value: 0.015657350253773118
# Gradient shape: (1, 10)
# Max gradient value: 0.008463229544226535
# Gradient shape: (784, 32)
# Max gradient value: 0.002651015701793245
# Gradient shape: (1, 32)
# Max gradient value: 0.02782950529968483
# Gradient shape: (32, 10)
# Max gradient value: 0.0161155398267996
# Gradient shape: (1, 10)
# Max gradient value: 0.008363065664095793
# Gradient shape: (784, 32)
# Max gradient value: 0.0022021193237836164
# Gradient shape: (1, 32)
# Max gradient value: 0.03190134043125338
# Gradient shape: (32, 10)
# Max gradient value: 0.019781786740933
# Gradient shape: (1, 10)
# Max gradient value: 0.00825211805093886
# Gradient shape: (784, 32)
# Max gradient value: 0.00108355953872091
# Gradient shape: (1, 32)
# Max gradient value: 0.035546350709869855
# Gradient shape: (32, 10)
# Max gradient value: 0.021977758621774403
# Gradient shape: (1, 10)
# Max gradient value: 0.00736918998310634
# Gradient shape: (784, 32)
# Max gradient value: 0.0011195530494933598
# Gradient shape: (1, 32)
# Max gradient value: 0.03474843939197027
# Gradient shape: (32, 10)
# Max gradient value: 0.020314059642711643
# Gradient shape: (1, 10)
# Max gradient value: 0.0061874284498145094
# Gradient shape: (784, 32)
# Max gradient value: 0.0004530517938993099
# Gradient shape: (1, 32)
# Max gradient value: 0.03323654710449653
# Gradient shape: (32, 10)
# Max gradient value: 0.015919092592870665
# Gradient shape: (1, 10)
# Max gradient value: 0.006993874225961786
# Gradient shape: (784, 32)
# Max gradient value: 4.0332251227828525e-05
# Gradient shape: (1, 32)
# Max gradient value: 0.03799750216950057
# Gradient shape: (32, 10)
# Max gradient value: 0.01509389601321268
# Gradient shape: (1, 10)
# Max gradient value: 0.008051105738028343
# Gradient shape: (784, 32)
# Max gradient value: 3.78136148735117e-05
# Gradient shape: (1, 32)
# Max gradient value: 0.03934721689741759
# Gradient shape: (32, 10)
# Max gradient value: 0.015053420988540374
# Gradient shape: (1, 10)
# Max gradient value: 0.007682135392156814
# Gradient shape: (784, 32)
# Max gradient value: 3.490969056184665e-05
# Gradient shape: (1, 32)
# Max gradient value: 0.03882023394852006
# Gradient shape: (32, 10)
# Max gradient value: 0.014289534240672051
# Gradient shape: (1, 10)
# Max gradient value: 0.007363768934593628
# Gradient shape: (784, 32)
# Max gradient value: 0.00014726528927845134
# Gradient shape: (1, 32)
# Max gradient value: 0.03355332453093271
# Gradient shape: (32, 10)
# Max gradient value: 0.014338504977435452
# Gradient shape: (1, 10)
# Max gradient value: 0.006821757375346144
# Gradient shape: (784, 32)
# Max gradient value: 0.0001540445453922099
# Gradient shape: (1, 32)
# Max gradient value: 0.03021516754072449
# Gradient shape: (32, 10)
# Max gradient value: 0.012924484463399078
# Gradient shape: (1, 10)
# Max gradient value: 0.007073776728778857
# Gradient shape: (784, 32)
# Max gradient value: 0.0030264312035934832
# Gradient shape: (1, 32)
# Max gradient value: 0.027481478126232826
# Gradient shape: (32, 10)
# Max gradient value: 0.015347729976835938
# Gradient shape: (1, 10)
# Max gradient value: 0.0067018675226492574
# Gradient shape: (784, 32)
# Max gradient value: 0.0027336591213182365
# Gradient shape: (1, 32)
# Max gradient value: 0.0262808250713173
# Gradient shape: (32, 10)
# Max gradient value: 0.011498617548640863
# Gradient shape: (1, 10)
# Max gradient value: 0.008246232091031029
# Gradient shape: (784, 32)
# Max gradient value: 0.004517756620855311
# Gradient shape: (1, 32)
# Max gradient value: 0.030185280463908382
# Gradient shape: (32, 10)
# Max gradient value: 0.011055326319977653
# Gradient shape: (1, 10)
# Max gradient value: 0.008088640195009367
# Gradient shape: (784, 32)
# Max gradient value: 0.0050162438141575375
# Gradient shape: (1, 32)
# Max gradient value: 0.028946405257915205
# Gradient shape: (32, 10)
# Max gradient value: 0.011160610744592342
# Gradient shape: (1, 10)
# Max gradient value: 0.008175698332850992
# Gradient shape: (784, 32)
# Max gradient value: 0.0037231387778655653
# Gradient shape: (1, 32)
# Max gradient value: 0.04153644835657497
# Gradient shape: (32, 10)
# Max gradient value: 0.010196911942483816
# Gradient shape: (1, 10)
# Max gradient value: 0.008728221989062333
# Gradient shape: (784, 32)
# Max gradient value: 0.0037723255774350273
# Gradient shape: (1, 32)
# Max gradient value: 0.022263395011152615
# Gradient shape: (32, 10)
# Max gradient value: 0.010363932042249498
# Gradient shape: (1, 10)
# Max gradient value: 0.008041987021962332
# Gradient shape: (784, 32)
# Max gradient value: 0.004756513884002942
# Gradient shape: (1, 32)
# Max gradient value: 0.02220012694076528
# Gradient shape: (32, 10)
# Max gradient value: 0.012745055929847923
# Gradient shape: (1, 10)
# Max gradient value: 0.00882201712077467
# Gradient shape: (784, 32)
# Max gradient value: 0.00791720057822412
# Gradient shape: (1, 32)
# Max gradient value: 0.024330999869521218
# Gradient shape: (32, 10)
# Max gradient value: 0.014557157864463835
# Gradient shape: (1, 10)
# Max gradient value: 0.007639166207111284
# Gradient shape: (784, 32)
# Max gradient value: 0.003948464979115748
# Gradient shape: (1, 32)
# Max gradient value: 0.025581095174757998
# Gradient shape: (32, 10)
# Max gradient value: 0.009627131434716614
# Gradient shape: (1, 10)
# Max gradient value: 0.008242847755170223
# Gradient shape: (784, 32)
# Max gradient value: 0.0028107587364987717
# Gradient shape: (1, 32)
# Max gradient value: 0.02425387745567609
# Gradient shape: (32, 10)
# Max gradient value: 0.006669587059949691
# Gradient shape: (1, 10)
# Max gradient value: 0.010788217049420028
# Gradient shape: (784, 32)
# Max gradient value: 0.00565384988976961
# Gradient shape: (1, 32)
# Max gradient value: 0.03168115765007908
# Gradient shape: (32, 10)
# Max gradient value: 0.007943810355630038
# Gradient shape: (1, 10)
# Max gradient value: 0.010668712721717433
# Gradient shape: (784, 32)
# Max gradient value: 0.0058211807445097095
# Gradient shape: (1, 32)
# Max gradient value: 0.019798374953640202
# Gradient shape: (32, 10)
# Max gradient value: 0.00608547476881705
# Gradient shape: (1, 10)
# Max gradient value: 0.008317857862196423
# Gradient shape: (784, 32)
# Max gradient value: 0.0030504853778380017
# Gradient shape: (1, 32)
# Max gradient value: 0.023622339788650176
# Gradient shape: (32, 10)
# Max gradient value: 0.005293831226129695
# Gradient shape: (1, 10)
# Max gradient value: 0.008249591795071473
# Gradient shape: (784, 32)
# Max gradient value: 0.007520678591765025
# Gradient shape: (1, 32)
# Max gradient value: 0.02784877096522083
# Gradient shape: (32, 10)
# Max gradient value: 0.011800389316753089
# Gradient shape: (1, 10)
# Max gradient value: 0.009833224114530968
# Gradient shape: (784, 32)
# Max gradient value: 0.012479846136652109
# Gradient shape: (1, 32)
# Max gradient value: 0.04757462436053708
# Gradient shape: (32, 10)
# Max gradient value: 0.017745860256829723
# Gradient shape: (1, 10)
# Max gradient value: 0.008735222551054399
# Gradient shape: (784, 32)
# Max gradient value: 0.011084153330012341
# Gradient shape: (1, 32)
# Max gradient value: 0.04252587170383773
# Gradient shape: (32, 10)
# Max gradient value: 0.01606680842415465
# Gradient shape: (1, 10)
# Max gradient value: 0.010926366190141847
# Gradient shape: (784, 32)
# Max gradient value: 0.006637825845908862
# Gradient shape: (1, 32)
# Max gradient value: 0.02074875265137126
# Gradient shape: (32, 10)
# Max gradient value: 0.008471569708594449
# Gradient shape: (1, 10)
# Max gradient value: 0.011678433446066477
# Gradient shape: (784, 32)
# Max gradient value: 0.006055213969416872
# Gradient shape: (1, 32)
# Max gradient value: 0.027662325692405742
# Gradient shape: (32, 10)
# Max gradient value: 0.007230248659103256
# Gradient shape: (1, 10)
# Max gradient value: 0.01053035864639677
# Gradient shape: (784, 32)
# Max gradient value: 0.0052318363083093435
# Gradient shape: (1, 32)
# Max gradient value: 0.020744268686398767
# Gradient shape: (32, 10)
# Max gradient value: 0.005179537522919308
# Gradient shape: (1, 10)
# Max gradient value: 0.007716347495073772
# Gradient shape: (784, 32)
# Max gradient value: 0.0064537942705621
# Gradient shape: (1, 32)
# Max gradient value: 0.018630578869683268
# Gradient shape: (32, 10)
# Max gradient value: 0.0038217638325540836
# Gradient shape: (1, 10)
# Max gradient value: 0.00673126073851233
# Gradient shape: (784, 32)
# Max gradient value: 0.007654754843408329
# Gradient shape: (1, 32)
# Max gradient value: 0.02822588454129847
# Gradient shape: (32, 10)
# Max gradient value: 0.006169421492302932
# Gradient shape: (1, 10)
# Max gradient value: 0.007214844095874091
# Gradient shape: (784, 32)
# Max gradient value: 0.00949109286031801
# Gradient shape: (1, 32)
# Max gradient value: 0.028177789266358534
# Gradient shape: (32, 10)
# Max gradient value: 0.009695420905192218
# Gradient shape: (1, 10)
# Max gradient value: 0.007298559788278471
# Gradient shape: (784, 32)
# Max gradient value: 0.009091291208734574
# Gradient shape: (1, 32)
# Max gradient value: 0.019436063315025873
# Gradient shape: (32, 10)
# Max gradient value: 0.010127167087512089
# Gradient shape: (1, 10)
# Max gradient value: 0.0059151336425726005
# Gradient shape: (784, 32)
# Max gradient value: 0.004772169550366661
# Gradient shape: (1, 32)
# Max gradient value: 0.013655447071494853
# Gradient shape: (32, 10)
# Max gradient value: 0.007277208498797705
# Gradient shape: (1, 10)
# Max gradient value: 0.0080122181627431
# Gradient shape: (784, 32)
# Max gradient value: 0.005403063683004877
# Gradient shape: (1, 32)
# Max gradient value: 0.015132717769938695
# Gradient shape: (32, 10)
# Max gradient value: 0.0040843650287775025
# Gradient shape: (1, 10)
# Max gradient value: 0.009536211450148956
# Gradient shape: (784, 32)
# Max gradient value: 0.006366761638366177
# Gradient shape: (1, 32)
# Max gradient value: 0.024492797172709316
# Gradient shape: (32, 10)
# Max gradient value: 0.0052709784556102405
# Gradient shape: (1, 10)
# Max gradient value: 0.00914240285489905
# Gradient shape: (784, 32)
# Max gradient value: 0.0068726212157609705
# Gradient shape: (1, 32)
# Max gradient value: 0.03267617404660091
# Gradient shape: (32, 10)
# Max gradient value: 0.007350207431023942
# Gradient shape: (1, 10)
# Max gradient value: 0.006587803326584719
# Gradient shape: (784, 32)
# Max gradient value: 0.008556173143094144
# Gradient shape: (1, 32)
# Max gradient value: 0.015672620171018354
# Gradient shape: (32, 10)
# Max gradient value: 0.006955526882217183
# Gradient shape: (1, 10)
# Max gradient value: 0.005848852867113669
# Gradient shape: (784, 32)
# Max gradient value: 0.007845519329677917
# Gradient shape: (1, 32)
# Max gradient value: 0.01875439056074595
# Gradient shape: (32, 10)
# Max gradient value: 0.007021596576096056
# Gradient shape: (1, 10)
# Max gradient value: 0.004906806129792335
# Gradient shape: (784, 32)
# Max gradient value: 0.00554204787784302
# Gradient shape: (1, 32)
# Max gradient value: 0.013330285160735537
# Gradient shape: (32, 10)
# Max gradient value: 0.004446835711895317
# Gradient shape: (1, 10)
# Max gradient value: 0.004811869991686248
# Gradient shape: (784, 32)
# Max gradient value: 0.006723028148628756
# Gradient shape: (1, 32)
# Max gradient value: 0.015685388324159402
# Gradient shape: (32, 10)
# Max gradient value: 0.004452213473468547
# Gradient shape: (1, 10)
# Max gradient value: 0.004499192769555356
# Gradient shape: (784, 32)
# Max gradient value: 0.006467598102656939
# Gradient shape: (1, 32)
# Max gradient value: 0.017048982853167007
# Gradient shape: (32, 10)
# Max gradient value: 0.0029588557576621707
# Gradient shape: (1, 10)
# Max gradient value: 0.004189865140210631
# Gradient shape: (784, 32)
# Max gradient value: 0.0037224424214049126
# Gradient shape: (1, 32)
# Max gradient value: 0.01249848986821408
# Gradient shape: (32, 10)
# Max gradient value: 0.0026303972388274036
# Gradient shape: (1, 10)
# Max gradient value: 0.005069785184815084
# Gradient shape: (784, 32)
# Max gradient value: 0.004457716584633894
# Gradient shape: (1, 32)
# Max gradient value: 0.01504071947745415
# Gradient shape: (32, 10)
# Max gradient value: 0.003433992221921911
# Gradient shape: (1, 10)
# Max gradient value: 0.005371597935772118
# Gradient shape: (784, 32)
# Max gradient value: 0.004734629863025058
# Gradient shape: (1, 32)
# Max gradient value: 0.01650300460645605
# Gradient shape: (32, 10)
# Max gradient value: 0.003648921751121246
# Gradient shape: (1, 10)
# Max gradient value: 0.006202494226534288
# Gradient shape: (784, 32)
# Max gradient value: 0.006558565557854152
# Gradient shape: (1, 32)
# Max gradient value: 0.019275283283963742
# Gradient shape: (32, 10)
# Max gradient value: 0.00508551240465126
# Gradient shape: (1, 10)
# Max gradient value: 0.005401910837425304
# Gradient shape: (784, 32)
# Max gradient value: 0.006835148332237411
# Gradient shape: (1, 32)
# Max gradient value: 0.01928610960937085
# Gradient shape: (32, 10)
# Max gradient value: 0.005981051373747005
# Gradient shape: (1, 10)
# Max gradient value: 0.004931086234637356
# Gradient shape: (784, 32)
# Max gradient value: 0.00606817228916782
# Gradient shape: (1, 32)
# Max gradient value: 0.020767959526877412
# Gradient shape: (32, 10)
# Max gradient value: 0.005823732403448126
# Gradient shape: (1, 10)
# Max gradient value: 0.005937279894037059
# Gradient shape: (784, 32)
# Max gradient value: 0.006826742430890233
# Gradient shape: (1, 32)
# Max gradient value: 0.020329105945878365
# Gradient shape: (32, 10)
# Max gradient value: 0.005115384823334483
# Gradient shape: (1, 10)
# Max gradient value: 0.006045830549532432
# Gradient shape: (784, 32)
# Max gradient value: 0.00861401102639978
# Gradient shape: (1, 32)
# Max gradient value: 0.015377804277482863
# Gradient shape: (32, 10)
# Max gradient value: 0.004474363714410697
# Gradient shape: (1, 10)
# Max gradient value: 0.0059472383515126615
# Gradient shape: (784, 32)
# Max gradient value: 0.007747609873231442
# Gradient shape: (1, 32)
# Max gradient value: 0.018682797280020962
# Gradient shape: (32, 10)
# Max gradient value: 0.005177493348039592
# Gradient shape: (1, 10)
# Max gradient value: 0.0049900281061922526
# Gradient shape: (784, 32)
# Max gradient value: 0.006341188415748933
# Gradient shape: (1, 32)
# Max gradient value: 0.016352774226879908
# Gradient shape: (32, 10)
# Max gradient value: 0.005162231065847055
# Gradient shape: (1, 10)
# Max gradient value: 0.004971441581681855
# Gradient shape: (784, 32)
# Max gradient value: 0.007321807443101959
# Gradient shape: (1, 32)
# Max gradient value: 0.01987699628948262
# Gradient shape: (32, 10)
# Max gradient value: 0.006372169701359504
# Gradient shape: (1, 10)
# Max gradient value: 0.005900612736860772
# Gradient shape: (784, 32)
# Max gradient value: 0.008399037924261006
# Gradient shape: (1, 32)
# Max gradient value: 0.022930339874296313
# Gradient shape: (32, 10)
# Max gradient value: 0.006758136831298929
# Gradient shape: (1, 10)
# Max gradient value: 0.0044018265900709385
# Gradient shape: (784, 32)
# Max gradient value: 0.005235278177820843
# Gradient shape: (1, 32)
# Max gradient value: 0.01900195272212827
# Gradient shape: (32, 10)
# Max gradient value: 0.0067203799714151006
# Gradient shape: (1, 10)
# Max gradient value: 0.004571418488402311
# Gradient shape: (784, 32)
# Max gradient value: 0.004541699777274325
# Gradient shape: (1, 32)
# Max gradient value: 0.01470210478848441
# Gradient shape: (32, 10)
# Max gradient value: 0.005314203145462398
# Gradient shape: (1, 10)
# Max gradient value: 0.007533329783182654
# Gradient shape: (784, 32)
# Max gradient value: 0.005387962038976662
# Gradient shape: (1, 32)
# Max gradient value: 0.023273579212864683
# Gradient shape: (32, 10)
# Max gradient value: 0.007719821705660611
# Gradient shape: (1, 10)
# Max gradient value: 0.008516082112860531
# Gradient shape: (784, 32)
# Max gradient value: 0.0072404911012263345
# Gradient shape: (1, 32)
# Max gradient value: 0.02603986039599511
# Gradient shape: (32, 10)
# Max gradient value: 0.008487717771598347
# Gradient shape: (1, 10)
# Max gradient value: 0.00824814058426215
# Gradient shape: (784, 32)
# Max gradient value: 0.0062490575162753095
# Gradient shape: (1, 32)
# Max gradient value: 0.020060484603013587
# Gradient shape: (32, 10)
# Max gradient value: 0.006234173946000478
# Gradient shape: (1, 10)
# Max gradient value: 0.006375937556537548
# Gradient shape: (784, 32)
# Max gradient value: 0.0050976330572460125
# Gradient shape: (1, 32)
# Max gradient value: 0.014844053331296927
# Gradient shape: (32, 10)
# Max gradient value: 0.004280449672773268
# Gradient shape: (1, 10)
# Max gradient value: 0.005098473410068475
# Gradient shape: (784, 32)
# Max gradient value: 0.00271752214118775
# Gradient shape: (1, 32)
# Max gradient value: 0.016091450074473438
# Gradient shape: (32, 10)
# Max gradient value: 0.0024618365020073413
# Gradient shape: (1, 10)
# Max gradient value: 0.005003768062645074
# Gradient shape: (784, 32)
# Max gradient value: 0.004433243500396667
# Gradient shape: (1, 32)
# Max gradient value: 0.015842044916417993
# Gradient shape: (32, 10)
# Max gradient value: 0.0053863847630497876
# Gradient shape: (1, 10)
# Max gradient value: 0.004704761070299119
# Gradient shape: (784, 32)
# Max gradient value: 0.006720792769008969
# Gradient shape: (1, 32)
# Max gradient value: 0.024396334285377262
# Gradient shape: (32, 10)
# Max gradient value: 0.008884771522299183
# Gradient shape: (1, 10)
# Max gradient value: 0.00491930273182767
# Gradient shape: (784, 32)
# Max gradient value: 0.006864293149027853
# Gradient shape: (1, 32)
# Max gradient value: 0.025274328314810454
# Gradient shape: (32, 10)
# Max gradient value: 0.009335414147591346
# Gradient shape: (1, 10)
# Max gradient value: 0.004172399159668822
# Gradient shape: (784, 32)
# Max gradient value: 0.006558543155794071
# Gradient shape: (1, 32)
# Max gradient value: 0.01660281318568229
# Gradient shape: (32, 10)
# Max gradient value: 0.0072905845849347796
# Gradient shape: (1, 10)
# Max gradient value: 0.004241618006420393
# Gradient shape: (784, 32)
# Max gradient value: 0.006939700132661913
# Gradient shape: (1, 32)
# Max gradient value: 0.013424441739547686
# Gradient shape: (32, 10)
# Max gradient value: 0.005678135848560711
# Gradient shape: (1, 10)
# Max gradient value: 0.004388871115119329
# Gradient shape: (784, 32)
# Max gradient value: 0.005552530449106788
# Gradient shape: (1, 32)
# Max gradient value: 0.01343598672786651
# Gradient shape: (32, 10)
# Max gradient value: 0.003160315075474786
# Gradient shape: (1, 10)
# Max gradient value: 0.004796420698074822
# Gradient shape: (784, 32)
# Max gradient value: 0.003820532618470587
# Gradient shape: (1, 32)
# Max gradient value: 0.017245737317408184
# Gradient shape: (32, 10)
# Max gradient value: 0.006081918302506587
# Gradient shape: (1, 10)
# Max gradient value: 0.004688572413768492
# Gradient shape: (784, 32)
# Max gradient value: 0.00481983138431524
# Gradient shape: (1, 32)
# Max gradient value: 0.020646926703046263
# Gradient shape: (32, 10)
# Max gradient value: 0.008086386629724837
# Gradient shape: (1, 10)
# Max gradient value: 0.005232700738117944
# Gradient shape: (784, 32)
# Max gradient value: 0.005360185716191549
# Gradient shape: (1, 32)
# Max gradient value: 0.0171290417186063
# Gradient shape: (32, 10)
# Max gradient value: 0.006797939336655132
# Gradient shape: (1, 10)
# Max gradient value: 0.004830173420503809
# Gradient shape: (784, 32)
# Max gradient value: 0.004851189162749437
# Gradient shape: (1, 32)
# Max gradient value: 0.009997588942315826
# Gradient shape: (32, 10)
# Max gradient value: 0.004514788808496918
# Gradient shape: (1, 10)
# Max gradient value: 0.0051616525004290065
# Gradient shape: (784, 32)
# Max gradient value: 0.006351218836336137
# Gradient shape: (1, 32)
# Max gradient value: 0.01636785207408656
# Gradient shape: (32, 10)
# Max gradient value: 0.004372138772747176
# Gradient shape: (1, 10)
# Max gradient value: 0.005826644676805776
# Gradient shape: (784, 32)
# Max gradient value: 0.008346409209846535
# Gradient shape: (1, 32)
# Max gradient value: 0.024212500091838788
# Gradient shape: (32, 10)
# Max gradient value: 0.006444630028925204
# Gradient shape: (1, 10)
# Max gradient value: 0.005448553724081406
# Gradient shape: (784, 32)
# Max gradient value: 0.00619902168964815
# Gradient shape: (1, 32)
# Max gradient value: 0.01989328764071743
# Gradient shape: (32, 10)
# Max gradient value: 0.005153216564671645
# Gradient shape: (1, 10)
# Max gradient value: 0.004404205890185743
# Gradient shape: (784, 32)
# Max gradient value: 0.003246395530743905
# Gradient shape: (1, 32)
# Max gradient value: 0.014446219710441972
# Gradient shape: (32, 10)
# Max gradient value: 0.0042275643408504196
# Gradient shape: (1, 10)
# Max gradient value: 0.0048732607471703975
# Gradient shape: (784, 32)
# Max gradient value: 0.004625952477754599
# Gradient shape: (1, 32)
# Max gradient value: 0.02130223650310813
# Gradient shape: (32, 10)
# Max gradient value: 0.004995868740223252
# Gradient shape: (1, 10)
# Max gradient value: 0.003720998885460793
# Gradient shape: (784, 32)
# Max gradient value: 0.002289875721777616
# Gradient shape: (1, 32)
# Max gradient value: 0.013388707758652807
# Gradient shape: (32, 10)
# Max gradient value: 0.0019571512605343283
# Gradient shape: (1, 10)
# Max gradient value: 0.0043249496641106855
# Gradient shape: (784, 32)
# Max gradient value: 0.005323014762440337
# Gradient shape: (1, 32)
# Max gradient value: 0.009026988945438132
# Gradient shape: (32, 10)
# Max gradient value: 0.0023468862629982723
# Gradient shape: (1, 10)
# Max gradient value: 0.003940378598413288
# Gradient shape: (784, 32)
# Max gradient value: 0.00572761799412594
# Gradient shape: (1, 32)
# Max gradient value: 0.015428092251621811
# Gradient shape: (32, 10)
# Max gradient value: 0.0039390817323105756
# Gradient shape: (1, 10)
# Max gradient value: 0.004313400711191247
# Gradient shape: (784, 32)
# Max gradient value: 0.005131230977583152
# Gradient shape: (1, 32)
# Max gradient value: 0.015323875137972027
# Gradient shape: (32, 10)
# Max gradient value: 0.003885698015911016
# Gradient shape: (1, 10)
# Max gradient value: 0.004564512019934107
# Gradient shape: (784, 32)
# Max gradient value: 0.005058413981923434
# Gradient shape: (1, 32)
# Max gradient value: 0.012036126724989302
# Gradient shape: (32, 10)
# Max gradient value: 0.0032582962711232883
# Gradient shape: (1, 10)
# Max gradient value: 0.00473927256734106
# Gradient shape: (784, 32)
# Max gradient value: 0.0040234008704185245
# Gradient shape: (1, 32)
# Max gradient value: 0.012389140801359057
# Gradient shape: (32, 10)
# Max gradient value: 0.0038404877263117647
# Gradient shape: (1, 10)
# Max gradient value: 0.00417038445159506
# Gradient shape: (784, 32)
# Max gradient value: 0.003983604165045747
# Gradient shape: (1, 32)
# Max gradient value: 0.015564850228580214
# Gradient shape: (32, 10)
# Max gradient value: 0.0019638006812680176
# Gradient shape: (1, 10)
# Max gradient value: 0.0037164226292945596
# Gradient shape: (784, 32)
# Max gradient value: 0.003578244378416845
# Gradient shape: (1, 32)
# Max gradient value: 0.013165891230119351
# Gradient shape: (32, 10)
# Max gradient value: 0.002100685697847009
# Gradient shape: (1, 10)
# Max gradient value: 0.004067556167384794
# Gradient shape: (784, 32)
# Max gradient value: 0.005180206969306411
# Gradient shape: (1, 32)
# Max gradient value: 0.013401558694753334
# Gradient shape: (32, 10)
# Max gradient value: 0.003239443438207274
# Gradient shape: (1, 10)
# Max gradient value: 0.004544444808569975
# Gradient shape: (784, 32)
# Max gradient value: 0.004766687049623295
# Gradient shape: (1, 32)
# Max gradient value: 0.011993693089421427
# Gradient shape: (32, 10)
# Max gradient value: 0.005281241725823031
# Gradient shape: (1, 10)
# Max gradient value: 0.005167992139491045
# Gradient shape: (784, 32)
# Max gradient value: 0.003680940365590323
# Gradient shape: (1, 32)
# Max gradient value: 0.008169564197109704
# Gradient shape: (32, 10)
# Max gradient value: 0.0033415216230118098
# Gradient shape: (1, 10)
# Max gradient value: 0.003826094045636372
# Gradient shape: (784, 32)
# Max gradient value: 0.003395929581148338
# Gradient shape: (1, 32)
# Max gradient value: 0.008800511019190084
# Gradient shape: (32, 10)
# Max gradient value: 0.003247171200684391
# Gradient shape: (1, 10)
# Max gradient value: 0.00401372334419124
# Gradient shape: (784, 32)
# Max gradient value: 0.00354362454006804
# Gradient shape: (1, 32)
# Max gradient value: 0.009991509166484945
# Gradient shape: (32, 10)
# Max gradient value: 0.002073330222049111
# Gradient shape: (1, 10)
# Max gradient value: 0.0039438159494598205
# Gradient shape: (784, 32)
# Max gradient value: 0.004426897488906588
# Gradient shape: (1, 32)
# Max gradient value: 0.010141758174198438
# Gradient shape: (32, 10)
# Max gradient value: 0.002416184983602938
# Gradient shape: (1, 10)
# Max gradient value: 0.0051619535260433395
# Gradient shape: (784, 32)
# Max gradient value: 0.006115175669741539
# Gradient shape: (1, 32)
# Max gradient value: 0.014769577731530873
# Gradient shape: (32, 10)
# Max gradient value: 0.004065792616217331
# Gradient shape: (1, 10)
# Max gradient value: 0.004654875995797409
# Gradient shape: (784, 32)
# Max gradient value: 0.00538830125061809
# Gradient shape: (1, 32)
# Max gradient value: 0.017828162082556852
# Gradient shape: (32, 10)
# Max gradient value: 0.005178819087473275
# Gradient shape: (1, 10)
# Max gradient value: 0.004306410915059522
# Gradient shape: (784, 32)
# Max gradient value: 0.0037139234175735765
# Gradient shape: (1, 32)
# Max gradient value: 0.01529859384276686
# Gradient shape: (32, 10)
# Max gradient value: 0.0030851616483462563
# Gradient shape: (1, 10)
# Max gradient value: 0.004338067836463541
# Gradient shape: (784, 32)
# Max gradient value: 0.004584780018767025
# Gradient shape: (1, 32)
# Max gradient value: 0.012258144983683434
# Gradient shape: (32, 10)
# Max gradient value: 0.002895840435767769
# Gradient shape: (1, 10)
# Max gradient value: 0.0048097635191119556
# Gradient shape: (784, 32)
# Max gradient value: 0.004605993324125742
# Gradient shape: (1, 32)
# Max gradient value: 0.011785578884450327
# Gradient shape: (32, 10)
# Max gradient value: 0.0028864729402585595
# Gradient shape: (1, 10)
# Max gradient value: 0.0069013066694225255
# Gradient shape: (784, 32)
# Max gradient value: 0.005771568998503647
# Gradient shape: (1, 32)
# Max gradient value: 0.013544162905607202
# Gradient shape: (32, 10)
# Max gradient value: 0.0043162995591304225
# Gradient shape: (1, 10)
# Max gradient value: 0.005693715686796552
# Gradient shape: (784, 32)
# Max gradient value: 0.00545820634516144
# Gradient shape: (1, 32)
# Max gradient value: 0.009438225284146316
# Gradient shape: (32, 10)
# Max gradient value: 0.005494846580736088
# Gradient shape: (1, 10)
# Max gradient value: 0.00494630099227376
# Gradient shape: (784, 32)
# Max gradient value: 0.005092426287987758
# Gradient shape: (1, 32)
# Max gradient value: 0.009981424250414988
# Gradient shape: (32, 10)
# Max gradient value: 0.006040114284064229
# Gradient shape: (1, 10)
# Max gradient value: 0.004398361879861843
# Gradient shape: (784, 32)
# Max gradient value: 0.0059398230192712394
# Gradient shape: (1, 32)
# Max gradient value: 0.013803272068440134
# Gradient shape: (32, 10)
# Max gradient value: 0.006856383265453062
# Gradient shape: (1, 10)
# Max gradient value: 0.003966353593193439
# Gradient shape: (784, 32)
# Max gradient value: 0.0053131836721702335
# Gradient shape: (1, 32)
# Max gradient value: 0.012878967339766461
# Gradient shape: (32, 10)
# Max gradient value: 0.006284193782780285
# Gradient shape: (1, 10)
# Max gradient value: 0.0032093804153278263
# Gradient shape: (784, 32)
# Max gradient value: 0.0030657412689321438
# Gradient shape: (1, 32)
# Max gradient value: 0.011282538241157741
# Gradient shape: (32, 10)
# Max gradient value: 0.0035719873104672686
# Gradient shape: (1, 10)
# Max gradient value: 0.0038867636063170913
# Gradient shape: (784, 32)
# Max gradient value: 0.0057619716540422555
# Gradient shape: (1, 32)
# Max gradient value: 0.012501203078733262
# Gradient shape: (32, 10)
# Max gradient value: 0.0022863156118214526
# Gradient shape: (1, 10)
# Max gradient value: 0.004814709618603492
# Gradient shape: (784, 32)
# Max gradient value: 0.005407908569869647
# Gradient shape: (1, 32)
# Max gradient value: 0.010158352984987512
# Gradient shape: (32, 10)
# Max gradient value: 0.002901718835889285
# Gradient shape: (1, 10)
# Max gradient value: 0.004907574229396298
# Gradient shape: (784, 32)
# Max gradient value: 0.004259229327062372
# Gradient shape: (1, 32)
# Max gradient value: 0.011111888172237617
# Gradient shape: (32, 10)
# Max gradient value: 0.003084719037785223
# Gradient shape: (1, 10)
# Max gradient value: 0.00340849729665396
# Gradient shape: (784, 32)
# Max gradient value: 0.0031809794395453546
# Gradient shape: (1, 32)
# Max gradient value: 0.011570367785132811
# Gradient shape: (32, 10)
# Max gradient value: 0.0027918304333803667
# Gradient shape: (1, 10)
# Max gradient value: 0.0039449637163644306
# Gradient shape: (784, 32)
# Max gradient value: 0.0037486436969277814
# Gradient shape: (1, 32)
# Max gradient value: 0.013473036327163634
# Gradient shape: (32, 10)
# Max gradient value: 0.0017039834067946796
# Gradient shape: (1, 10)
# Max gradient value: 0.004236938622798267
# Gradient shape: (784, 32)
# Max gradient value: 0.006949787974949545
# Gradient shape: (1, 32)
# Max gradient value: 0.009250287874265855
# Gradient shape: (32, 10)
# Max gradient value: 0.004372755818633407
# Gradient shape: (1, 10)
# Max gradient value: 0.004870697944006913
# Gradient shape: (784, 32)
# Max gradient value: 0.008756652715470718
# Gradient shape: (1, 32)
# Max gradient value: 0.014129353846042872
# Gradient shape: (32, 10)
# Max gradient value: 0.0067624866950488395
# Gradient shape: (1, 10)
# Max gradient value: 0.005691025053308074
# Gradient shape: (784, 32)
# Max gradient value: 0.009161911772098179
# Gradient shape: (1, 32)
# Max gradient value: 0.019931739831796327
# Gradient shape: (32, 10)
# Max gradient value: 0.0086866178822884
# Gradient shape: (1, 10)
# Max gradient value: 0.004279387280107377
# Gradient shape: (784, 32)
# Max gradient value: 0.005546715118312425
# Gradient shape: (1, 32)
# Max gradient value: 0.016703497889986797
# Gradient shape: (32, 10)
# Max gradient value: 0.006622794251035425
# Gradient shape: (1, 10)
# Max gradient value: 0.0037513915452302925
# Gradient shape: (784, 32)
# Max gradient value: 0.004339777933701395
# Gradient shape: (1, 32)
# Max gradient value: 0.010177880229139992
# Gradient shape: (32, 10)
# Max gradient value: 0.004058719755467748
# Gradient shape: (1, 10)
# Max gradient value: 0.003610262790029419
# Gradient shape: (784, 32)
# Max gradient value: 0.0027925267671570515
# Gradient shape: (1, 32)
# Max gradient value: 0.012294970278726901
# Gradient shape: (32, 10)
# Max gradient value: 0.0030002634578833393
# Gradient shape: (1, 10)
# Max gradient value: 0.0032456938870426087
# Gradient shape: (784, 32)
# Max gradient value: 0.003226837381874526
# Gradient shape: (1, 32)
# Max gradient value: 0.01194448041039364
# Gradient shape: (32, 10)
# Max gradient value: 0.003112332219527539
# Gradient shape: (1, 10)
# Max gradient value: 0.003107839611839436
# Gradient shape: (784, 32)
# Max gradient value: 0.002670309179469323
# Gradient shape: (1, 32)
# Max gradient value: 0.010806837572472692
# Gradient shape: (32, 10)
# Max gradient value: 0.0025301490878415545
# Gradient shape: (1, 10)
# Max gradient value: 0.0038452071846381553
# Gradient shape: (784, 32)
# Max gradient value: 0.003586894072361319
# Gradient shape: (1, 32)
# Max gradient value: 0.01362930927004451
# Gradient shape: (32, 10)
# Max gradient value: 0.0031163937691447187
# Gradient shape: (1, 10)
# Max gradient value: 0.004588886020900034
# Gradient shape: (784, 32)
# Max gradient value: 0.003282155272248362
# Gradient shape: (1, 32)
# Max gradient value: 0.013100195072513815
# Gradient shape: (32, 10)
# Max gradient value: 0.00302008254014823
# Gradient shape: (1, 10)
# Max gradient value: 0.00401400806686997
# Gradient shape: (784, 32)
# Max gradient value: 0.004249118616496501
# Gradient shape: (1, 32)
# Max gradient value: 0.011200764219745982
# Gradient shape: (32, 10)
# Max gradient value: 0.003016514090310294
# Gradient shape: (1, 10)
# Max gradient value: 0.0034298458920444556
# Gradient shape: (784, 32)
# Max gradient value: 0.0034388237104555474
# Gradient shape: (1, 32)
# Max gradient value: 0.015593559614767534
# Gradient shape: (32, 10)
# Max gradient value: 0.005168799480162261
# Gradient shape: (1, 10)
# Max gradient value: 0.003481205764858667
# Gradient shape: (784, 32)
# Max gradient value: 0.0037517067836885494
# Gradient shape: (1, 32)
# Max gradient value: 0.014270399051069686
# Gradient shape: (32, 10)
# Max gradient value: 0.004738407605220673
# Gradient shape: (1, 10)
# Max gradient value: 0.0037063090975691495
# Gradient shape: (784, 32)
# Max gradient value: 0.004498434653117054
# Gradient shape: (1, 32)
# Max gradient value: 0.018173570450381357
# Gradient shape: (32, 10)
# Max gradient value: 0.005475342031480435
# Gradient shape: (1, 10)
# Max gradient value: 0.003914302874237117
# Gradient shape: (784, 32)
# Max gradient value: 0.002384665909571172
# Gradient shape: (1, 32)
# Max gradient value: 0.009897998114954669
# Gradient shape: (32, 10)
# Max gradient value: 0.00300808867172516
# Gradient shape: (1, 10)
# Max gradient value: 0.003951364748262226
# Gradient shape: (784, 32)
# Max gradient value: 0.001963943152006169
# Gradient shape: (1, 32)
# Max gradient value: 0.012639897622770626
# Gradient shape: (32, 10)
# Max gradient value: 0.0036093849014952302
# Gradient shape: (1, 10)
# Max gradient value: 0.004822337935216439
# Gradient shape: (784, 32)
# Max gradient value: 0.0026541317324106925
# Gradient shape: (1, 32)
# Max gradient value: 0.012187183925405584
# Gradient shape: (32, 10)
# Max gradient value: 0.0030839007599776235
# Gradient shape: (1, 10)
# Max gradient value: 0.0043243296537032044
# Gradient shape: (784, 32)
# Max gradient value: 0.004104033907225226
# Gradient shape: (1, 32)
# Max gradient value: 0.015997888338586102
# Gradient shape: (32, 10)
# Max gradient value: 0.003730430950168295
# Gradient shape: (1, 10)
# Max gradient value: 0.004342148823560498
# Gradient shape: (784, 32)
# Max gradient value: 0.00465006940351786
# Gradient shape: (1, 32)
# Max gradient value: 0.01648919288245838
# Gradient shape: (32, 10)
# Max gradient value: 0.0038804865200642133
# Gradient shape: (1, 10)
# Max gradient value: 0.006262491133947978
# Gradient shape: (784, 32)
# Max gradient value: 0.002978636184757772
# Gradient shape: (1, 32)
# Max gradient value: 0.020044111347098267
# Gradient shape: (32, 10)
# Max gradient value: 0.004596484147279083
# Gradient shape: (1, 10)
# Max gradient value: 0.005059526869115962
# Gradient shape: (784, 32)
# Max gradient value: 0.0029228346094957486
# Gradient shape: (1, 32)
# Max gradient value: 0.009858330422920553
# Gradient shape: (32, 10)
# Max gradient value: 0.002203977429106567
# Gradient shape: (1, 10)
# Max gradient value: 0.006835987703751571
# Gradient shape: (784, 32)
# Max gradient value: 0.0042195783622233606
# Gradient shape: (1, 32)
# Max gradient value: 0.01316250190790225
# Gradient shape: (32, 10)
# Max gradient value: 0.0032980763825360957
# Gradient shape: (1, 10)
# Max gradient value: 0.0059295626963267005
# Gradient shape: (784, 32)
# Max gradient value: 0.004155795177215049
# Gradient shape: (1, 32)
# Max gradient value: 0.013108854339232475
# Gradient shape: (32, 10)
# Max gradient value: 0.003973979936377044
# Gradient shape: (1, 10)
# Max gradient value: 0.005122895983721712
# Gradient shape: (784, 32)
# Max gradient value: 0.0026109103602380275
# Gradient shape: (1, 32)
# Max gradient value: 0.013613178177152815
# Gradient shape: (32, 10)
# Max gradient value: 0.0036106115051453723
# Gradient shape: (1, 10)
# Max gradient value: 0.0032979259329711306
# Gradient shape: (784, 32)
# Max gradient value: 0.0031448166378224285
# Gradient shape: (1, 32)
# Max gradient value: 0.014400323987523115
# Gradient shape: (32, 10)
# Max gradient value: 0.0042305237936714046
# Gradient shape: (1, 10)
# Max gradient value: 0.0032180901879679986
# Gradient shape: (784, 32)
# Max gradient value: 0.002671813221454514
# Gradient shape: (1, 32)
# Max gradient value: 0.015717354973413842
# Gradient shape: (32, 10)
# Max gradient value: 0.0028331500719050787
# Gradient shape: (1, 10)
# Max gradient value: 0.0036225553591684298
# Gradient shape: (784, 32)
# Max gradient value: 0.0037536457925907317
# Gradient shape: (1, 32)
# Max gradient value: 0.011187084221790537
# Gradient shape: (32, 10)
# Max gradient value: 0.003375305371014789
# Gradient shape: (1, 10)
# Max gradient value: 0.0045962625730194715
# Gradient shape: (784, 32)
# Max gradient value: 0.004165389940809517
# Gradient shape: (1, 32)
# Max gradient value: 0.010146099966071942
# Gradient shape: (32, 10)
# Max gradient value: 0.004017662912436386
# Gradient shape: (1, 10)
# Max gradient value: 0.004303667274234303
# Gradient shape: (784, 32)
# Max gradient value: 0.00463265064075358
# Gradient shape: (1, 32)
# Max gradient value: 0.010714172133012281
# Gradient shape: (32, 10)
# Max gradient value: 0.004584269929810248
# Gradient shape: (1, 10)
# Max gradient value: 0.003742757562365
# Gradient shape: (784, 32)
# Max gradient value: 0.0038192885907978847
# Gradient shape: (1, 32)
# Max gradient value: 0.009597171294196022
# Gradient shape: (32, 10)
# Max gradient value: 0.004094707789254328
# Gradient shape: (1, 10)
# Max gradient value: 0.003993850947710275
# Gradient shape: (784, 32)
# Max gradient value: 0.003978325007738878
# Gradient shape: (1, 32)
# Max gradient value: 0.007720892372874434
# Gradient shape: (32, 10)
# Max gradient value: 0.003428860856510233
# Gradient shape: (1, 10)
# Max gradient value: 0.0037812660486850097
# Gradient shape: (784, 32)
# Max gradient value: 0.003914388557074227
# Gradient shape: (1, 32)
# Max gradient value: 0.011675363219643591
# Gradient shape: (32, 10)
# Max gradient value: 0.0031144203110217822
# Gradient shape: (1, 10)
# Max gradient value: 0.0041370767184774
# Gradient shape: (784, 32)
# Max gradient value: 0.004432075665935587
# Gradient shape: (1, 32)
# Max gradient value: 0.009797591306090656
# Gradient shape: (32, 10)
# Max gradient value: 0.0024725860125831955
# Gradient shape: (1, 10)
# Max gradient value: 0.004554103784273361
# Gradient shape: (784, 32)
# Max gradient value: 0.004969018242115715
# Gradient shape: (1, 32)
# Max gradient value: 0.009665979859744584
# Gradient shape: (32, 10)
# Max gradient value: 0.0030657457278425943
# Gradient shape: (1, 10)
# Max gradient value: 0.004613275362387495
# Gradient shape: (784, 32)
# Max gradient value: 0.00578392307816681
# Gradient shape: (1, 32)
# Max gradient value: 0.009705785452995608
# Gradient shape: (32, 10)
# Max gradient value: 0.0031925085103879664
# Gradient shape: (1, 10)
# Max gradient value: 0.0051174936751558105
# Gradient shape: (784, 32)
# Max gradient value: 0.006091124895956162
# Gradient shape: (1, 32)
# Max gradient value: 0.010230850796920727
# Gradient shape: (32, 10)
# Max gradient value: 0.002454821089464175
# Gradient shape: (1, 10)
# Max gradient value: 0.005432101239467326
# Gradient shape: (784, 32)
# Max gradient value: 0.0054580919515406804
# Gradient shape: (1, 32)
# Max gradient value: 0.013729264589067126
# Gradient shape: (32, 10)
# Max gradient value: 0.0029960846347061613
# Gradient shape: (1, 10)
# Max gradient value: 0.004988288742738071
# Gradient shape: (784, 32)
# Max gradient value: 0.005232997629869332
# Gradient shape: (1, 32)
# Max gradient value: 0.014527597907417087
# Gradient shape: (32, 10)
# Max gradient value: 0.0032628146629047608
# Gradient shape: (1, 10)
# Max gradient value: 0.004333096050160467
# Gradient shape: (784, 32)
# Max gradient value: 0.004123487692123658
# Gradient shape: (1, 32)
# Max gradient value: 0.010977138882226234
# Gradient shape: (32, 10)
# Max gradient value: 0.0025579964077854104
# Gradient shape: (1, 10)
# Max gradient value: 0.004760314201044599
# Gradient shape: (784, 32)
# Max gradient value: 0.003973053374063195
# Gradient shape: (1, 32)
# Max gradient value: 0.010688741395160009
# Gradient shape: (32, 10)
# Max gradient value: 0.002654991619889231
# Gradient shape: (1, 10)
# Max gradient value: 0.0038920861244390857
# Gradient shape: (784, 32)
# Max gradient value: 0.0034122481449426877
# Gradient shape: (1, 32)
# Max gradient value: 0.01640479001804998
# Gradient shape: (32, 10)
# Max gradient value: 0.0037370356928845424
# Gradient shape: (1, 10)
# Max gradient value: 0.003954017862515834
# Gradient shape: (784, 32)
# Max gradient value: 0.002371181717417605
# Gradient shape: (1, 32)
# Max gradient value: 0.011672906950694844
# Gradient shape: (32, 10)
# Max gradient value: 0.002242697443453368
# Gradient shape: (1, 10)
# Max gradient value: 0.0036813902073575197
# Gradient shape: (784, 32)
# Max gradient value: 0.002232098626958198
# Gradient shape: (1, 32)
# Max gradient value: 0.012231073581593827
# Gradient shape: (32, 10)
# Max gradient value: 0.003282398725555285
# Gradient shape: (1, 10)
# Max gradient value: 0.003146431657739219
# Gradient shape: (784, 32)
# Max gradient value: 0.002336872463949931
# Gradient shape: (1, 32)
# Max gradient value: 0.007617342420458722
# Gradient shape: (32, 10)
# Max gradient value: 0.002413400858678909
# Gradient shape: (1, 10)
# Max gradient value: 0.0031651743297677437
# Gradient shape: (784, 32)
# Max gradient value: 0.0028449110925329608
# Gradient shape: (1, 32)
# Max gradient value: 0.00632424906133537
# Gradient shape: (32, 10)
# Max gradient value: 0.0021178226170516373
# Gradient shape: (1, 10)
# Max gradient value: 0.003879463542760336
# Gradient shape: (784, 32)
# Max gradient value: 0.00406050297648102
# Gradient shape: (1, 32)
# Max gradient value: 0.005394310813991493
# Gradient shape: (32, 10)
# Max gradient value: 0.002121336795852778
# Gradient shape: (1, 10)
# Max gradient value: 0.004309339198193045
# Gradient shape: (784, 32)
# Max gradient value: 0.004831487376204884
# Gradient shape: (1, 32)
# Max gradient value: 0.007167346307018544
# Gradient shape: (32, 10)
# Max gradient value: 0.0024555907801266856
# Gradient shape: (1, 10)
# Max gradient value: 0.004580201501186775
# Gradient shape: (784, 32)
# Max gradient value: 0.005195772370882879
# Gradient shape: (1, 32)
# Max gradient value: 0.008235796543126991
# Gradient shape: (32, 10)
# Max gradient value: 0.0026808954282626397
# Gradient shape: (1, 10)
# Max gradient value: 0.003907992813802524
# Gradient shape: (784, 32)
# Max gradient value: 0.003613045052357354
# Gradient shape: (1, 32)
# Max gradient value: 0.018444927240963777
# Gradient shape: (32, 10)
# Max gradient value: 0.0039268318589127885
# Gradient shape: (1, 10)
# Max gradient value: 0.004971833981935434
# Gradient shape: (784, 32)
# Max gradient value: 0.006872965233608579
# Gradient shape: (1, 32)
# Max gradient value: 0.020773680923057813
# Gradient shape: (32, 10)
# Max gradient value: 0.004755420379832129
# Gradient shape: (1, 10)
# Max gradient value: 0.004293205283006799
# Gradient shape: (784, 32)
# Max gradient value: 0.0056486627995856785
# Gradient shape: (1, 32)
# Max gradient value: 0.01927068553109668
# Gradient shape: (32, 10)
# Max gradient value: 0.004415000115777142
# Gradient shape: (1, 10)
# Max gradient value: 0.0038272508945924426
# Gradient shape: (784, 32)
# Max gradient value: 0.0037593148791549864
# Gradient shape: (1, 32)
# Max gradient value: 0.01174908070916458
# Gradient shape: (32, 10)
# Max gradient value: 0.0032056488086495334
# Gradient shape: (1, 10)
# Max gradient value: 0.004006515495468662
# Gradient shape: (784, 32)
# Max gradient value: 0.0025647730664317323
# Gradient shape: (1, 32)
# Max gradient value: 0.008402108181375888
# Gradient shape: (32, 10)
# Max gradient value: 0.002361847858047078
# Gradient shape: (1, 10)
# Max gradient value: 0.004419411149324934
# Gradient shape: (784, 32)
# Max gradient value: 0.004497720834206765
# Gradient shape: (1, 32)
# Max gradient value: 0.02003950532232432
# Gradient shape: (32, 10)
# Max gradient value: 0.004110432970045731
# Gradient shape: (1, 10)
# Max gradient value: 0.004944698052352505
# Gradient shape: (784, 32)
# Max gradient value: 0.006278852502384952
# Gradient shape: (1, 32)
# Max gradient value: 0.018204017079215144
# Gradient shape: (32, 10)
# Max gradient value: 0.0031861092741803376
# Gradient shape: (1, 10)
# Max gradient value: 0.005012930241309187
# ...
# Gradient shape: (784, 32)
# Max gradient value: 0.001548181509913046
# Gradient shape: (1, 32)
# Max gradient value: 0.007643763491442087
# Gradient shape: (32, 10)
# Max gradient value: 0.000989670617232056
# Gradient shape: (1, 10)
# Max gradient value: 0.0029757994795676234
# Gradient shape: (784, 32)
# Max gradient value: 0.001626361085445527
# Gradient shape: (1, 32)
# Max gradient value: 0.008177997921248977
# Gradient shape: (32, 10)
# Max gradient value: 0.0011586984130315184
# Gradient shape: (1, 10)
# Max gradient value: 0.002751766670249023
# Gradient shape: (784, 32)
# Max gradient value: 0.0017207070265620964
# Gradient shape: (1, 32)
# Max gradient value: 0.005609380554602096
# Gradient shape: (32, 10)
# Max gradient value: 0.0012796322973868833
# Gradient shape: (1, 10)
# Max gradient value: 0.002571925537822098
# Gradient shape: (784, 32)
# Max gradient value: 0.0021504025432818588
# Gradient shape: (1, 32)
# Max gradient value: 0.006586732269498966
# Gradient shape: (32, 10)
# Max gradient value: 0.001713394078662779
# Gradient shape: (1, 10)
# Max gradient value: 0.0037536659292616444
# Gradient shape: (784, 32)
# Max gradient value: 0.00361244187157865
# Gradient shape: (1, 32)
# Max gradient value: 0.010394207505406703
# Gradient shape: (32, 10)
# Max gradient value: 0.002475924493120467
# Gradient shape: (1, 10)
# Max gradient value: 0.0038333435673850646
# Gradient shape: (784, 32)
# Max gradient value: 0.0036173792967709273
# Gradient shape: (1, 32)
# Max gradient value: 0.01021468291126373
# Gradient shape: (32, 10)
# Max gradient value: 0.0026475711090236907
# Gradient shape: (1, 10)
# Max gradient value: 0.003845810298291042
# Gradient shape: (784, 32)
# Max gradient value: 0.004464190710641148
# Gradient shape: (1, 32)
# Max gradient value: 0.010484017170695558
# Gradient shape: (32, 10)
# Max gradient value: 0.002795866272265109
# Gradient shape: (1, 10)
# Max gradient value: 0.004071320794409187
# Gradient shape: (784, 32)
# Max gradient value: 0.004250533877199291
# Gradient shape: (1, 32)
# Max gradient value: 0.009533204077779675
# Gradient shape: (32, 10)
# Max gradient value: 0.0025889119769051836
# Gradient shape: (1, 10)
# Max gradient value: 0.0031582745370205526
# Gradient shape: (784, 32)
# Max gradient value: 0.0037411868355749656
# Gradient shape: (1, 32)
# Max gradient value: 0.007427757006397259
# Gradient shape: (32, 10)
# Max gradient value: 0.0019706647531756716
# Gradient shape: (1, 10)
# Max gradient value: 0.002624145028861362
# Gradient shape: (784, 32)
# Max gradient value: 0.0026738854257290206
# Gradient shape: (1, 32)
# Max gradient value: 0.006310741094418203
# Gradient shape: (32, 10)
# Max gradient value: 0.0017090479670851693
# Gradient shape: (1, 10)
# Max gradient value: 0.003019493619571936
# Gradient shape: (784, 32)
# Max gradient value: 0.00319547419083872
# Gradient shape: (1, 32)
# Max gradient value: 0.006276689502819981
# Gradient shape: (32, 10)
# Max gradient value: 0.0020066004836516824
# Gradient shape: (1, 10)
# Max gradient value: 0.0033534032594018156
# Gradient shape: (784, 32)
# Max gradient value: 0.003318337306045773
# Gradient shape: (1, 32)
# Max gradient value: 0.006733930024277653
# Gradient shape: (32, 10)
# Max gradient value: 0.0021194927937363962
# Gradient shape: (1, 10)
# Max gradient value: 0.0035584314888737222
# Gradient shape: (784, 32)
# Max gradient value: 0.0030127869317754428
# Gradient shape: (1, 32)
# Max gradient value: 0.00729882971199893
# Gradient shape: (32, 10)
# Max gradient value: 0.0020902435975574834
# Gradient shape: (1, 10)
# Max gradient value: 0.0028745803914545596
# Gradient shape: (784, 32)
# Max gradient value: 0.002546363843843822
# Gradient shape: (1, 32)
# Max gradient value: 0.006192134992536136
# Gradient shape: (32, 10)
# Max gradient value: 0.0013659524296580168
# Gradient shape: (1, 10)
# Max gradient value: 0.0026349957535001514
# Gradient shape: (784, 32)
# Max gradient value: 0.003066968925214169
# Gradient shape: (1, 32)
# Max gradient value: 0.005612321171810676
# Gradient shape: (32, 10)
# Max gradient value: 0.000881326168879322
# Gradient shape: (1, 10)
# Max gradient value: 0.0029020625595294032
# Gradient shape: (784, 32)
# Max gradient value: 0.0025939218141396918
# Gradient shape: (1, 32)
# Max gradient value: 0.00594049480320349
# Gradient shape: (32, 10)
# Max gradient value: 0.0007131840952668634
# Gradient shape: (1, 10)
# Max gradient value: 0.00258720146141122
# Gradient shape: (784, 32)
# Max gradient value: 0.002721906370053281
# Gradient shape: (1, 32)
# Max gradient value: 0.009505445263512324
# Gradient shape: (32, 10)
# Max gradient value: 0.0013507489728937904
# Gradient shape: (1, 10)
# Max gradient value: 0.0029806403083670664
# Gradient shape: (784, 32)
# Max gradient value: 0.00323647800413724
# Gradient shape: (1, 32)
# Max gradient value: 0.012444549269524274
# Gradient shape: (32, 10)
# Max gradient value: 0.0023584185235860002
# Gradient shape: (1, 10)
# Max gradient value: 0.0028170141999479988
# Gradient shape: (784, 32)
# Max gradient value: 0.002783324113048686
# Gradient shape: (1, 32)
# Max gradient value: 0.013941943247308615
# Gradient shape: (32, 10)
# Max gradient value: 0.002258146512606641
# Gradient shape: (1, 10)
# Max gradient value: 0.003196146233814496
# Gradient shape: (784, 32)
# Max gradient value: 0.0031441864829914318
# Gradient shape: (1, 32)
# Max gradient value: 0.01204463741827538
# Gradient shape: (32, 10)
# Max gradient value: 0.002434328261539275
# Gradient shape: (1, 10)
# Max gradient value: 0.002719171732795164
# Gradient shape: (784, 32)
# Max gradient value: 0.002281650899502486
# Gradient shape: (1, 32)
# Max gradient value: 0.011341086754945034
# Gradient shape: (32, 10)
# Max gradient value: 0.001784746316326376
# Gradient shape: (1, 10)
# Max gradient value: 0.0029318976542392077
# Gradient shape: (784, 32)
# Max gradient value: 0.0023296671699553607
# Gradient shape: (1, 32)
# Max gradient value: 0.008837997664340904
# Gradient shape: (32, 10)
# Max gradient value: 0.0009465464402488695
# Gradient shape: (1, 10)
# Max gradient value: 0.003116574188161774
# Gradient shape: (784, 32)
# Max gradient value: 0.002374203337525009
# Gradient shape: (1, 32)
# Max gradient value: 0.011444602829636365
# Gradient shape: (32, 10)
# Max gradient value: 0.0019364545253458768
# Gradient shape: (1, 10)
# Max gradient value: 0.0029746082688068016
# Gradient shape: (784, 32)
# Max gradient value: 0.0024196630431776818
# Gradient shape: (1, 32)
# Max gradient value: 0.012532890207415114
# Gradient shape: (32, 10)
# Max gradient value: 0.0022072851345772736
# Gradient shape: (1, 10)
# Max gradient value: 0.0033120435917688134
# Gradient shape: (784, 32)
# Max gradient value: 0.0029395914636593107
# Gradient shape: (1, 32)
# Max gradient value: 0.007904206150190208
# Gradient shape: (32, 10)
# Max gradient value: 0.0017518674171822812
# Gradient shape: (1, 10)
# Max gradient value: 0.003151403774348019
# Gradient shape: (784, 32)
# Max gradient value: 0.0032307774370679784
# Gradient shape: (1, 32)
# Max gradient value: 0.006854124730728046
# Gradient shape: (32, 10)
# Max gradient value: 0.0011263385416748891
# Gradient shape: (1, 10)
# Max gradient value: 0.0034318854913053184
# Gradient shape: (784, 32)
# Max gradient value: 0.0035403866242933115
# Gradient shape: (1, 32)
# Max gradient value: 0.00826025759414441
# Gradient shape: (32, 10)
# Max gradient value: 0.0012805671600732331
# Gradient shape: (1, 10)
# Max gradient value: 0.0030834619244338554
# Gradient shape: (784, 32)
# Max gradient value: 0.0029498521110110565
# Gradient shape: (1, 32)
# Max gradient value: 0.007070784499570749
# Gradient shape: (32, 10)
# Max gradient value: 0.0011989865352867127
# Gradient shape: (1, 10)
# Max gradient value: 0.0027266492825791257
# Gradient shape: (784, 32)
# Max gradient value: 0.002773371653308023
# Gradient shape: (1, 32)
# Max gradient value: 0.0058309821163321516
# Gradient shape: (32, 10)
# Max gradient value: 0.0012383505633476437
# Gradient shape: (1, 10)
# Max gradient value: 0.002316571529946766
# Gradient shape: (784, 32)
# Max gradient value: 0.0017165580480992125
# Gradient shape: (1, 32)
# Max gradient value: 0.005504719372675262
# Gradient shape: (32, 10)
# Max gradient value: 0.0017272974012650182
# Gradient shape: (1, 10)
# Max gradient value: 0.0022954162710731914
# Gradient shape: (784, 32)
# Max gradient value: 0.001974981920532547
# Gradient shape: (1, 32)
# Max gradient value: 0.005204673028652955
# Gradient shape: (32, 10)
# Max gradient value: 0.0015716555691464875
# Gradient shape: (1, 10)
# Max gradient value: 0.002654176200756422
# Gradient shape: (784, 32)
# Max gradient value: 0.002977924437592821
# Gradient shape: (1, 32)
# Max gradient value: 0.00514703577116223
# Gradient shape: (32, 10)
# Max gradient value: 0.0014797340076275975
# Gradient shape: (1, 10)
# Max gradient value: 0.0029646627307882137
# Gradient shape: (784, 32)
# Max gradient value: 0.0030289172404377967
# Gradient shape: (1, 32)
# Max gradient value: 0.006860560925675541
# Gradient shape: (32, 10)
# Max gradient value: 0.0016036036734021967
# Gradient shape: (1, 10)
# Max gradient value: 0.0026793112077783746
# Gradient shape: (784, 32)
# Max gradient value: 0.0026038397393297647
# Gradient shape: (1, 32)
# Max gradient value: 0.007225971386103464
# Gradient shape: (32, 10)
# Max gradient value: 0.0018883826388603386
# Gradient shape: (1, 10)
# Max gradient value: 0.0025280378841946115
# Gradient shape: (784, 32)
# Max gradient value: 0.002363633861362385
# Gradient shape: (1, 32)
# Max gradient value: 0.008526300867310745
# Gradient shape: (32, 10)
# Max gradient value: 0.002060334120978938
# Gradient shape: (1, 10)
# Max gradient value: 0.0025300994931814766
# Gradient shape: (784, 32)
# Max gradient value: 0.0022030924652591084
# Gradient shape: (1, 32)
# Max gradient value: 0.007324011429841144
# Gradient shape: (32, 10)
# Max gradient value: 0.0017184440689076293
# Gradient shape: (1, 10)
# Max gradient value: 0.002707720895700989
# Gradient shape: (784, 32)
# Max gradient value: 0.0024856865936124604
# Gradient shape: (1, 32)
# Max gradient value: 0.0063675461610756415
# Gradient shape: (32, 10)
# Max gradient value: 0.001456137276868621
# Gradient shape: (1, 10)
# Max gradient value: 0.0025241270250133617
# Gradient shape: (784, 32)
# Max gradient value: 0.002467040324366304
# Gradient shape: (1, 32)
# Max gradient value: 0.005018720488910695
# Gradient shape: (32, 10)
# Max gradient value: 0.0010986481315226604
# Gradient shape: (1, 10)
# Max gradient value: 0.0025708648514368984
# Gradient shape: (784, 32)
# Max gradient value: 0.002096722973381571
# Gradient shape: (1, 32)
# Max gradient value: 0.006166585696697048
# Gradient shape: (32, 10)
# Max gradient value: 0.0007966294557782425
# Gradient shape: (1, 10)
# Max gradient value: 0.002757705018681324
# Gradient shape: (784, 32)
# Max gradient value: 0.00179984548951436
# Gradient shape: (1, 32)
# Max gradient value: 0.006689542144172606
# Gradient shape: (32, 10)
# Max gradient value: 0.0009240653568359169
# Gradient shape: (1, 10)
# Max gradient value: 0.002401138678941976
# Gradient shape: (784, 32)
# Max gradient value: 0.0022680929135689056
# Gradient shape: (1, 32)
# Max gradient value: 0.009587652662085977
# Gradient shape: (32, 10)
# Max gradient value: 0.0016019130831122115
# Gradient shape: (1, 10)
# Max gradient value: 0.0020818421614422176
# Gradient shape: (784, 32)
# Max gradient value: 0.0022101797399099875
# Gradient shape: (1, 32)
# Max gradient value: 0.007830630931831265
# Gradient shape: (32, 10)
# Max gradient value: 0.0011049371068413572
# Gradient shape: (1, 10)
# Max gradient value: 0.002271918337236398
# Gradient shape: (784, 32)
# Max gradient value: 0.002634476884754496
# Gradient shape: (1, 32)
# Max gradient value: 0.0074405335061415254
# Gradient shape: (32, 10)
# Max gradient value: 0.0010275080601141592
# Gradient shape: (1, 10)
# Max gradient value: 0.002260101820391767
# Gradient shape: (784, 32)
# Max gradient value: 0.0021331463605075854
# Gradient shape: (1, 32)
# Max gradient value: 0.00662761196116734
# Gradient shape: (32, 10)
# Max gradient value: 0.0014161234998410262
# Gradient shape: (1, 10)
# Max gradient value: 0.0025750958622278064
# Gradient shape: (784, 32)
# Max gradient value: 0.002382835727530681
# Gradient shape: (1, 32)
# Max gradient value: 0.00872122996568516
# Gradient shape: (32, 10)
# Max gradient value: 0.0018506177279303975
# Gradient shape: (1, 10)
# Max gradient value: 0.0019226823772163831
# Gradient shape: (784, 32)
# Max gradient value: 0.0016230019225314772
# Gradient shape: (1, 32)
# Max gradient value: 0.0052515917229480355
# Gradient shape: (32, 10)
# Max gradient value: 0.0011488114446679594
# Gradient shape: (1, 10)
# Max gradient value: 0.0018239210346201996
# Gradient shape: (784, 32)
# Max gradient value: 0.0014197444183584648
# Gradient shape: (1, 32)
# Max gradient value: 0.00734137807132632
# Gradient shape: (32, 10)
# Max gradient value: 0.0015935603707860917
# Gradient shape: (1, 10)
# Max gradient value: 0.0018007974098534184
# Gradient shape: (784, 32)
# Max gradient value: 0.0011180206926682643
# Gradient shape: (1, 32)
# Max gradient value: 0.005088555488972833
# Gradient shape: (32, 10)
# Max gradient value: 0.0011551642449886973
# Gradient shape: (1, 10)
# Max gradient value: 0.0020106209964926925
# Gradient shape: (784, 32)
# Max gradient value: 0.0014660591289127087
# Gradient shape: (1, 32)
# Max gradient value: 0.005361845883582386
# Gradient shape: (32, 10)
# Max gradient value: 0.0005811198116273866
# Gradient shape: (1, 10)
# Max gradient value: 0.0022930297653584912
# Gradient shape: (784, 32)
# Max gradient value: 0.0016093694151798335
# Gradient shape: (1, 32)
# Max gradient value: 0.009260453512618498
# Gradient shape: (32, 10)
# Max gradient value: 0.0008507067371940842
# Gradient shape: (1, 10)
# Max gradient value: 0.0024468468241015556
# Gradient shape: (784, 32)
# Max gradient value: 0.0016189118628692207
# Gradient shape: (1, 32)
# Max gradient value: 0.008841479642900918
# Gradient shape: (32, 10)
# Max gradient value: 0.0009334384415007604
# Gradient shape: (1, 10)
# Max gradient value: 0.002253734854110437
# Gradient shape: (784, 32)
# Max gradient value: 0.001705251151913834
# Gradient shape: (1, 32)
# Max gradient value: 0.008627653486442666
# Gradient shape: (32, 10)
# Max gradient value: 0.0020568025085068897
# Gradient shape: (1, 10)
# Max gradient value: 0.0023308297665333177
# Gradient shape: (784, 32)
# Max gradient value: 0.0018733729407534067
# Gradient shape: (1, 32)
# Max gradient value: 0.009692303361814737
# Gradient shape: (32, 10)
# Max gradient value: 0.0014214815115052442
# Gradient shape: (1, 10)
# Max gradient value: 0.0026867270763150184
# Gradient shape: (784, 32)
# Max gradient value: 0.002349089400244901
# Gradient shape: (1, 32)
# Max gradient value: 0.007262158297227714
# Gradient shape: (32, 10)
# Max gradient value: 0.002294623546858201
# Gradient shape: (1, 10)
# Max gradient value: 0.0029308295212438318
# Gradient shape: (784, 32)
# Max gradient value: 0.0024838963204690274
# Gradient shape: (1, 32)
# Max gradient value: 0.008414735465255889
# Gradient shape: (32, 10)
# Max gradient value: 0.0029022973027940176
# Gradient shape: (1, 10)
# Max gradient value: 0.0026423271077349194
# Gradient shape: (784, 32)
# Max gradient value: 0.0021968996905372203
# Gradient shape: (1, 32)
# Max gradient value: 0.007279380062553627
# Gradient shape: (32, 10)
# Max gradient value: 0.0024728917670117675
# Gradient shape: (1, 10)
# Max gradient value: 0.0029900709342457485
# Gradient shape: (784, 32)
# Max gradient value: 0.002018203316720682
# Gradient shape: (1, 32)
# Max gradient value: 0.004100445086696961
# Gradient shape: (32, 10)
# Max gradient value: 0.0011726739608411687
# Gradient shape: (1, 10)
# Max gradient value: 0.0027631367320664372
# Gradient shape: (784, 32)
# Max gradient value: 0.0020469993432401623
# Gradient shape: (1, 32)
# Max gradient value: 0.007285425322149531
# Gradient shape: (32, 10)
# Max gradient value: 0.0023919560501952162
# Gradient shape: (1, 10)
# Max gradient value: 0.0025578873495918104
# Gradient shape: (784, 32)
# Max gradient value: 0.0021297990625170626
# Gradient shape: (1, 32)
# Max gradient value: 0.005425962156223908
# Gradient shape: (32, 10)
# Max gradient value: 0.0021092939555310015
# Gradient shape: (1, 10)
# Max gradient value: 0.0036360103270984714
# Gradient shape: (784, 32)
# Max gradient value: 0.003497318228290063
# Gradient shape: (1, 32)
# Max gradient value: 0.006694927913210627
# Gradient shape: (32, 10)
# Max gradient value: 0.0013489907075864482
# Gradient shape: (1, 10)
# Loss = 0.00034643733200314937 | Training Accuracy = 0.9798666666666667 | Val Loss = 0.00032209511377631633 | Val Accuracy = 0.9664

# %% [markdown]
# #### fprop a single image and showing its prediction

# %%
plt.imshow(X_val[0].reshape(28,28), cmap='gray')

# %%
# Predict Scores for each class
prediction = nn.predict_scores(X_val[0])[0]

# %%
print ("Scores")
print (prediction)
# Out:
# Scores
# [ -2.72307928  -2.26205045   5.51604429   7.36422827  -8.7275836
#    0.03918395 -25.85977011  16.64578105   2.33453915   7.62716774]

# %%
np.argmax(prediction)
# Out:
# 7

# %%
predict_class = nn.predict(X_val[0])[0]
predict_class
# Out:
# 7

# %%
# Original class
y_val[0]
# Out:
# 7
